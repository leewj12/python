# %%
# 파일 읽기
# scores.txt 파일의 내용 :
# 김소영 82 80 93 97 93 88
# 정예린 86 100 93 86 90 77
# 이세영 91 88 99 79 92 68
# 정수정 86 100 93 89 92 93
# 박지수 80 100 95 89 90 84
file = open('scores.txt', 'r', encoding='utf8') # encoding='utf8' 생략가능 생략하면 디폴트값
lines = file.readlines() # read lines() 한줄씩 읽음( 리스트 형태 )
print(type(lines))
print(lines)
print()
for i in range(len(lines)):
    print(lines[i])
#--------------------------------
print('scores.txt 파일의 내용 : ')
for line in lines :
    print(line, end='')
    print(type(line))
file.close()
# Out:
# <class 'list'>
# ['김소영 82 80 93 97 93 88 \n', '정예린 86 100 93 86 90 77 \n', '이세영 91 88 99 79 92 68 \n', '정수정 86 100 93 89 92 93 \n', '박지수 80 100 95 89 90 84']
#
# 김소영 82 80 93 97 93 88
#
# 정예린 86 100 93 86 90 77
#
# 이세영 91 88 99 79 92 68
#
# 정수정 86 100 93 89 92 93
#
# 박지수 80 100 95 89 90 84
# scores.txt 파일의 내용 :
# 김소영 82 80 93 97 93 88
# <class 'str'>
# 정예린 86 100 93 86 90 77
# <class 'str'>
# 이세영 91 88 99 79 92 68
# <class 'str'>
# 정수정 86 100 93 89 92 93
# <class 'str'>
# 박지수 80 100 95 89 90 84<class 'str'>

# %%
# 파일쓰기
file = open('sample.txt', 'w', encoding='utf8')
file.write('안녕하세요. 반갑습니다.')
file.close()
print('sample.txt 파일 쓰기 완료!')
# Out:
# sample.txt 파일 쓰기 완료!

# %%
# 리스트를 파일로 저장
scores = ['김소영 82 80 93 97 93 88',
'정예린 86 100 93 86 90 77',
'이세영 91 88 99 79 92 68',
'정수정 86 100 93 89 92 93',
'박지수 80 100 95 89 90 84']
data = ''
for item in scores :
    data += item + '\n'
# 화면 출력하기
print(data)
# 파일(scores.csv)에  저장하기
file = open('scores.csv', 'w', encoding='utf8' )
file.write(data)
file.close()
# Out:
# 김소영 82 80 93 97 93 88
# 정예린 86 100 93 86 90 77
# 이세영 91 88 99 79 92 68
# 정수정 86 100 93 89 92 93
# 박지수 80 100 95 89 90 84

# %%
file = open('scores.txt', 'r', encoding='utf8') # encoding='utf8' 생략가능 생략하면 디폴트값
lines = file.readlines() # read lines() 한줄씩 읽음( 리스트 형태 )
data = ''
for item in lines :
    data += item
# 파일(scores.xls)에  저장하기
file = open('scores.xls', 'w', encoding='utf8' )
file.write(data)
print('scores.xls 쓰기 완료!')
file.close()
# Out:
# scores.xls 쓰기 완료!

# %%
# # 1. sample.txt 파일에 korea.txt 파일의 내용을 추가한 후 sample.txt 파일의 내용을 읽어서 출력
# file = open('sample.txt','r', encoding='utf8' )
# file2 = open('korea.txt','r', encoding='utf8' )

# print(file.readlines())

# %%
# 2. scores.txt 파일에 korea.txt 파일의 내용을 추가한 후 smaple.txt 파일의 내용을 읽어서 출력

# %%
#1. sample.txt파일에 korea.txt 파일의 내용을 추가한 후
#   sample.txt 파일의 내용을 읽어서 화면에 출력하세요
#korea 파일 열어서 읽기
file = open('korea.txt', 'r', encoding='utf8')
lines_kor = file.readlines()
#읽은 내용(list)을 str 형태로 바꾸기
data = ''
for item in lines_kor :
    data += item
    data += '\n' #가독성을 위해 마지막 문장에 줄바꿈 추가
file = open('sample.txt', 'a', encoding='utf8' )
file.write(data)    #data를 sample.txt에 추가
#읽기 모드로 열기
file = open('sample.txt', 'r', encoding='utf8' )
lines_sam = file.readlines()
for line in lines_sam:
    print(line, end = '')
file.close()
print("sample.txt 추가 완료")
# Out:
# 안녕하세요. 반갑습니다.동해물과 백두산이 마르고 닳도록
#
# 하느님이 보우하사 우리나라 만세
#
# 무궁화 삼천리 화려강산
#
# 대한사람 대한으로 길이 보전하세
#
#
#
# 남산위에 저 소나무 철갑을 두른듯
#
# 바람소리 불변함은 우리 기상일세
#
#
#
# 가을하늘 공활한데 높고 구름없이
#
# 밝은 달은 우리 가슴 일편단심일세
#
#
#
# 이 기상과 이 마음으로 충성을 다하여
#
# 괴로우나 이로우나 나라 사랑하세
# sample.txt 추가 완료

# %%
# Out:
#   Cell In[65], line 2
#     x = '%s님 안녕하세요.' % name
#     ^
# IndentationError: expected an indented block after function definition on line 1
