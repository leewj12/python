# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd

head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}
res = req.get('https://www.melon.com/chart/index.htm', headers = head)
html = res.text
soup = bs(html, 'lxml')

song = soup.select("div.ellipsis.rank01 > span > a") # list 형태로 결과 저장
singer = soup.select("div.ellipsis.rank02 > span.checkEllipsis") # list 형태로 결과 저장

song_list = []
singer_list = []
rank_list = []

print(len(song))
print(len(singer))

for i in range(len(song)):
    song_list.append(song[i].text)
    singer_list.append(singer[i].text)
    rank_list.append(i+1)
    print(rank_list[i], song_list[i], singer_list[i])

dic = {'순위': rank_list, '노래': song_list, '가수': singer_list}

melon = pd.DataFrame(dic) # 데이터프레임 melon에 값 저장
melon.set_index('순위',inplace=True)
melon.to_csv('멜론차트_utf-8.csv', encoding='utf-8')
melon.to_csv('멜론차트_euc-kr.csv', encoding='euc-kr')
melon.to_csv('멜론차트_utf-8-sig.csv', encoding='utf-8-sig')
# Out:
# 100
# 100
# 1 Supernova aespa
# 2 클락션 (Klaxon) (여자)아이들
# 3 How Sweet NewJeans
# 4 Sticky KISS OF LIFE
# 5 Small girl (feat. 도경수(D.O.)) 이영지
# 6 Supernatural NewJeans
# 7 소나기 이클립스 (ECLIPSE)
# 8 한 페이지가 될 수 있게 DAY6 (데이식스)
# 9 고민중독 QWER
# 10 Bubble Gum NewJeans
# 11 나는 아픈 건 딱 질색이니까 (여자)아이들
# 12 Welcome to the Show DAY6 (데이식스)
# 13 Armageddon aespa
# 14 사랑은 늘 도망가 임영웅
# 15 Magnetic 아일릿(ILLIT)
# 16 첫 만남은 계획대로 되지 않아 TWS (투어스)
# 17 해야 (HEYA) IVE (아이브)
# 18 예뻤어 DAY6 (데이식스)
# 19 온기 임영웅
# 20 우리들의 블루스 임영웅
# 21 SPOT! (feat. JENNIE) 지코 (ZICO)
# 22 천상연 이창섭
# 23 Home 임영웅
# 24 모래 알갱이 임영웅
# 25 다시 만날 수 있을까 임영웅
# 26 이제 나만 믿어요 임영웅
# 27 Do or Die 임영웅
# 28 에피소드 이무진
# 29 무지개 임영웅
# 30 London Boy 임영웅
# 31 Polaroid 임영웅
# 32 Boom Boom Bass RIIZE
# 33 인생찬가 임영웅
# 34 슬픈 초대장 순순희(지환)
# 35 미안해 미워해 사랑해 Crush
# 36 내가 S면 넌 나의 N이 되어줘 TWS (투어스)
# 37 Hype Boy NewJeans
# 38 연애편지 임영웅
# 39 Love wins all 아이유
# 40 비의 랩소디 임재현
# 41 Seven (feat. Latto) - Clean Ver. 정국
# 42 I AM IVE (아이브)
# 43 WAY 4 LUV PLAVE
# 44 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection)) 너드커넥션 (Nerd Connection)
# 45 보금자리 임영웅
# 46 오래된 노래 허각, 임한별, 이무진, 이진성 (먼데이 키즈), 김희재, #안녕
# 47 To. X 태연 (TAEYEON)
# 48 Attention NewJeans
# 49 ETA NewJeans
# 50 Super Shy NewJeans
# 51 헤어지자 말해요 박재정
# 52 우리 영화 PLAVE
# 53 밤양갱 비비 (BIBI)
# 54 From PLAVE
# 55 Drama aespa
# 56 너의 모든 순간 성시경
# 57 Ditto NewJeans
# 58 Watch Me Woo! PLAVE
# 59 SHEESH BABYMONSTER
# 60 청혼하지 않을 이유를 못 찾았어 이무진
# 61 버추얼 아이돌 PLAVE
# 62 사랑인가 봐 멜로망스
# 63 Spicy aespa
# 64 Dynamite 방탄소년단
# 65 주저하는 연인들을 위해 잔나비
# 66 사건의 지평선 윤하 (YOUNHA)
# 67 인사 범진
# 68 퀸카 (Queencard) (여자)아이들
# 69 LOVE DIVE IVE (아이브)
# 70 Girls Never Die tripleS (트리플에스)
# 71 파이팅 해야지 (Feat. 이영지) 부석순 (SEVENTEEN)
# 72 Cosmic Red Velvet (레드벨벳)
# 73 Accendio IVE (아이브)
# 74 Love 119 RIIZE
# 75 봄날 방탄소년단
# 76 Love Lee AKMU (악뮤)
# 77 Get A Guitar RIIZE
# 78 사막에서 꽃을 피우듯 우디 (Woody)
# 79 삐그덕 (Walk) NCT 127
# 80 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지 AKMU (악뮤)
# 81 모든 날, 모든 순간 (Every day, Every Moment) 폴킴
# 82 그랬나봐 유회승 (엔플라잉)
# 83 Perfect Night LE SSERAFIM (르세라핌)
# 84 다정히 내 이름을 부르면 경서예지, 전건호
# 85 OMG NewJeans
# 86 꿈 태연 (TAEYEON)
# 87 네가 내 마음에 자리 잡았다 (Into You) 엔플라잉 (N.Flying)
# 88 I Don't Think That I Like Her Charlie Puth
# 89 Live My Life aespa
# 90 MANIAC VIVIZ (비비지)
# 91 취중고백 김민석
# 92 Who 지민
# 93 봄눈 10CM
# 94 내가 그댈 하동균
# 95 Midas Touch KISS OF LIFE
# 96 MAESTRO 세븐틴 (SEVENTEEN)
# 97 Lucky Girl Syndrome 아일릿(ILLIT)
# 98 Right Now NewJeans
# 99 Supersonic 프로미스나인
# 100 Impossible RIIZE
