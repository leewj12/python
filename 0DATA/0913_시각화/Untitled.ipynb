# %%
#아래는 한글을 사용할 때 깨지는 문제에 대한 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

#그래프의 축 등에서 음수를 표시할 때 minus sign이 깨지는 것 해결
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

# %%
#pyplot

import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline #주피터 내부에 그림 표시하게 명령

#UsageError: unrecognized arguments:
# Out:
# UsageError: unrecognized arguments: #주피터 내부에 그림 표시하게 명령

# %%
import pandas as pd

# CSV 파일 불러오기 (파일 경로를 넣어주세요)
df = pd.read_csv('netflix_titles.csv')

# 데이터 출력
print(df)
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
df.sort_values(by=['type','release_year'])
# Out:
#      show_id     type                                          title  \
# 4960   s4961    Movie                                 Prelude to War
# 6117   s6118    Movie                           The Battle of Midway
# 7342   s7343    Movie  Undercover: How to Operate Behind Enemy Lines
# 7616   s7617    Movie             Why We Fight: The Battle of Russia
# 7679   s7680    Movie                WWII: Report from the Aleutians
# ...      ...      ...                                            ...
# 4468   s4469  TV Show    Night Stalker: The Hunt for a Serial Killer
# 4965   s4966  TV Show                            Pretend It’s a City
# 5921   s5922  TV Show                                Surviving Death
# 6477   s6478  TV Show                           The Idhun Chronicles
# 6701   s6702  TV Show                         The Netflix Afterparty
#
#                          director  \
# 4960                  Frank Capra
# 6117                    John Ford
# ...

# %%
mv = df[df['type'] == 'Movie']
mv.sort_values(by='release_year')
# Out:
#      show_id   type                                              title  \
# 4960   s4961  Movie                                     Prelude to War
# 6117   s6118  Movie                               The Battle of Midway
# 7616   s7617  Movie                 Why We Fight: The Battle of Russia
# 7342   s7343  Movie      Undercover: How to Operate Behind Enemy Lines
# 7679   s7680  Movie                    WWII: Report from the Aleutians
# ...      ...    ...                                                ...
# 7644   s7645  Movie                                           Wish You
# 1514   s1515  Movie            Crack: Cocaine, Corruption & Conspiracy
# 4710   s4711  Movie                                   Outside the Wire
# 5103   s5104  Movie  Ratones Paranoicos: The Band that Rocked Argen...
# 1355   s1356  Movie  Chris Rock Total Blackout: The Tamborine Exten...
#
#                              director  \
# 4960                      Frank Capra
# ...

# %%
mv_cnt = mv.groupby('release_year').size()
mv_cnt
# Out:
# release_year
# 1942      2
# 1943      3
# 1944      3
# 1945      3
# 1946      1
#        ...
# 2017    744
# 2018    734
# 2019    582
# 2020    411
# 2021     12
# Length: 72, dtype: int64

# %%
mv_cnt.sort_values(ascending=False).head(10)
# Out:
# release_year
# 2017    744
# 2018    734
# 2016    642
# 2019    582
# 2020    411
# 2015    382
# 2014    244
# 2013    202
# 2012    158
# 2010    136
# dtype: int64

# %%
#pyplot as plt
x = mv_cnt.sort_values(ascending=False).head(10)
c = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#9dd757', '#d16e79', '#dbda6c', '#2cdeda', '#6c6666', '#ecdddd'] 

# 막대 그래프 그리기
plt.bar(x.index, x.values, color=c)

# x축 라벨 설정
plt.xticks(x.index, x.index, rotation=45)  # 연도들을 라벨로 설정하고, 회전시켜 보기 좋게 만듦

# 그래프 보여주기
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

#아래는 한글을 사용할 때 깨지는 문제에 대한 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

#그래프의 축 등에서 음수를 표시할 때 minus sign이 깨지는 것 해결
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

# CSV 파일 불러오기 (파일 경로를 넣어주세요)
df = pd.read_csv('netflix_titles.csv')

#영화만 남기기
mv = df[df['type'] == 'Movie']
#연도별 영화 개수
mv_cnt = mv.groupby('release_year').size()
# 상위 10개
x = mv_cnt.sort_values(ascending=False).head(10)

ratio = x.values  # 영화 개수
labels = x.index  # 연도
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0', '#9dd757', '#d16e79', '#dbda6c', '#2cdeda', '#6c6666', '#799c67']  # 색상 지정
wedgeprops = {'width': 0.6, 'edgecolor': 'white', 'linewidth': 4}

# 파이 차트 그리기 (비율 대신 영화 개수 표시)
plt.pie(ratio, labels=[f'{label}년: {value}편' for label, value in zip(labels, ratio)], colors=colors, wedgeprops=wedgeprops, autopct='%.1f%%' )

# 그래프 제목 추가
plt.title('넷플릭스 영화 개봉년도 TOP10')

# 그래프 보여주기
plt.show()
