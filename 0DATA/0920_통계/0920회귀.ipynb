# %%
# %pip install tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.3/236.3 MB 18.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 31.8 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.1 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 MB 35.7 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.1/405.1 kB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 23.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.9/284.9 kB 33.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

x = np.array([2,4,6,8])
y = np.array([81,93,91,97])

model=Sequential()

model.add(Dense(1,input_dim=1,activation='linear'))

model.compile(optimizer='sgd',loss='mse')

model.fit(x,y,epochs=1000)

plt.scatter(x,y)
plt.plot(x,model.predict(x),'r')
plt.show()

hour=7
private_class=4
prediction=model.predict([[hour,private_class]])
print("%.f시간을 공부할 경우의 예상 점수는%.02f점입니다."%(hour,private_class,prediction))
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7782.9395
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1977.1218
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1119.0377
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 987.6871
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 963.1097
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 954.2490
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 947.7305
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 941.5900
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 935.5385
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 929.5332
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 923.5680
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 917.6416
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 911.7537
# Epoch 14/1000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 입력 데이터: 2차원 데이터로 변경 (각 행이 hour, private_class로 구성)
x = np.array([[2, 1], [4, 2], [6, 3], [8, 4]])
y = np.array([81, 93, 91, 97])

# 모델 생성
model = Sequential()
model.add(Dense(1, input_dim=2, activation='linear'))  # input_dim을 2로 설정

# 모델 컴파일
model.compile(optimizer='sgd', loss='mse')

# 모델 학습
model.fit(x, y, epochs=1000)

# 시각화: 첫 번째 입력 변수에 따라 시각화
plt.scatter(x[:, 0], y)
plt.plot(x[:, 0], model.predict(x), 'r')
plt.show()

# 예측: 7시간 공부하고 4회 과외 수업을 받은 경우
hour = 7
private_class = 4
prediction = model.predict([[hour, private_class]])
print("%.f시간을 공부하고 %.f회 과외 수업을 받을 경우의 예상 점수는 %.02f점입니다." % (hour, private_class, prediction))
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 7884.6802
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1365.2811
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1004.5127
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 978.8781
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 971.5172
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 965.1893
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 958.9566
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 952.7672
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 946.6183
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 940.5093
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 934.4401
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 928.4106
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 922.4202
# Epoch 14/1000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# 입력 데이터: 2차원 데이터로 변경 (각 행이 hour, private_class로 구성)
x = np.array([[2, 1], [4, 2], [6, 3], [8, 4]])
y = np.array([81, 93, 91, 97])

# 모델 생성
model = Sequential()
model.add(Dense(1, input_dim=2, activation='linear'))  # input_dim을 2로 설정

# 모델 컴파일
model.compile(optimizer='sgd', loss='mse')

# 모델 학습
model.fit(x, y, epochs=2000)

# 시각화: 첫 번째 입력 변수에 따라 시각화
plt.scatter(x[:, 0], y)
plt.plot(x[:, 0], model.predict(x), 'r')
plt.show()

# 예측: 7시간 공부하고 4회 과외 수업을 받은 경우
hour = 7
private_class = 4

# 입력 데이터를 numpy 배열로 변환하여 예측
prediction = model.predict(np.array([[hour, private_class]]))
print("%.f시간을 공부하고 %.f회 과외 수업을 받을 경우의 예상 점수는 %.02f점입니다." % (hour, private_class, prediction[0][0]))
# Out:
# Epoch 1/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 8908.2188
# Epoch 2/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1417.5310
# Epoch 3/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1003.9370
# Epoch 4/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 975.4504
# Epoch 5/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 967.9564
# Epoch 6/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 961.6434
# Epoch 7/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 955.4331
# Epoch 8/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 949.2667
# Epoch 9/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 943.1405
# Epoch 10/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 937.0541
# Epoch 11/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 931.0075
# Epoch 12/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 925.0002
# Epoch 13/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 919.0321
# Epoch 14/2000
# ...
